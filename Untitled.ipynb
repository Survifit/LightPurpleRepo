# %%
# Import Dependencies
import pandas as pd

# %%
primary_csv = "primary_merge.csv"

# %%
primary_df = pd.read_csv(primary_csv)

# %%
primary_df.head()
# Out:
#    Unnamed: 0_x                                             Actors  \
# 0             0  Charlize Theron, Christina Ricci, Bruce Dern, ...
# 1             1  Devon Alan, Laura Harris, Zooey Deschanel, Mar...
# 2             2  Halle Berry, Robert Downey Jr., Charles S. Dut...
# 3             3  Sean Connery, Naseeruddin Shah, Peta Wilson, T...
# 4             4  Pamela Anderson, Jenny McCarthy, Marny Eng, Ch...
#
#                                            Awards    BoxOffice  \
# 0  Won 1 Oscar. Another 29 wins & 25 nominations.  $34,187,787
# 1                                   1 nomination.          NaN
# 2                         3 wins & 7 nominations.  $59,537,388
# 3                                 12 nominations.  $66,327,144
# 4                         2 wins & 4 nominations.          NaN
#
#                             Country          DVD            Director  Episode  \
# 0                      Germany, USA  01 Jun 2004       Patty Jenkins      NaN
# ...
